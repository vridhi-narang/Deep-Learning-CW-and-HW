# %% [markdown]
# <a href="https://colab.research.google.com/github/vridhi-narang/Deep-Learning-CW-and-HW/blob/master/Exercise_2_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Codes by Vridhi
#1
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import pandas as pd

# %%
#2
dataframe=pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv')
dataframe.head()
# Out:
#    symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0          3                122  alfa-romero  ...            Medium      0   1
# 1          3                122  alfa-romero  ...            Medium      0   1
# 2          1                122  alfa-romero  ...            Medium      0   1
# 3          2                164         audi  ...            Medium      0   1
# 4          2                164         audi  ...            Medium      0   1
#
# [5 rows x 29 columns]

# %%
dataframe.shape
# Out:
# (201, 29)

# %%
dataframe.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#4
dataframe['engine-size'].corr(dataframe['price'])
# Out:
# 0.8723351674455198

# %%
#5
dataframe.corr()['price']
# Out:
# symboling           -0.082391
# normalized-losses    0.133999
# wheel-base           0.584642
# length               0.690628
# width                0.751265
# height               0.135486
# curb-weight          0.834415
# engine-size          0.872335
# bore                 0.543155
# stroke               0.082310
# compression-ratio    0.071107
# horsepower           0.809575
# peak-rpm            -0.101616
# city-mpg            -0.686571
# highway-mpg         -0.704692
# price                1.000000
# city-L/100km         0.789898
# diesel               0.110326
# gas                 -0.110326
# Name: price, dtype: float64

# %%
#6
dataframe['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
sns.regplot(dataframe['engine-size'],dataframe['price'])
print('By seeing the plot we can say that the correlation is positive if engine-size increases also the price increases')
# Out:
# By seeing the plot we can say that the correlation is positive if engine-size increases also the price increases

# %%
#8
for i in dataframe.corr()['price'].keys():
    sns.regplot(dataframe[i],dataframe['price'])

# %%
sns.pairplot(dataframe,y_vars=['price'],x_vars=dataframe.select_dtypes('float64').columns,kind='reg')

# %%
#10
plt.figure(figsize=(15,11))
ax = sns.heatmap(dataframe.corr(), annot=True, cmap="coolwarm")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
#11
sns.boxplot(dataframe['body-style'],dataframe['price'])

# %%
#12
sns.boxplot(x=dataframe["price"],y=dataframe["engine-type"])

# %%
sns.boxplot(x=dataframe["price"],y=dataframe["num-of-doors"])

# %%
sns.boxplot(x=dataframe["price"],y=dataframe["drive-wheels"])

# %%
sns.boxplot(x=dataframe["price"],y=dataframe["num-of-cylinders"])

# %%
sns.boxplot(x=dataframe["price"],y=dataframe["fuel-system"])

# %%
"""""
Boxplot tells us about the outliers and what their values are, it can also tell us if our data is symmetrical and
how tightly our data is grouped.
from the above boxplots, we can observe the outliers in the different variables, maximum and minimum values of each
unique categorical values in each column and how much they vary from each other w.r.t price.

'""\nBoxplot tells us about the outliers and what their values are, it can also tell us if our data is symmetrical and\nhow tightly our data is grouped.\nfrom the above boxplots, we can observe the outliers in the different variables, maximum and minimum values of each\nunique categorical values in each column and how much they vary from each other w.r.t price.\n\n'

"""""
# Out:
# '""\nBoxplot tells us about the outliers and what their values are, it can also tell us if our data is symmetrical and\nhow tightly our data is grouped.\nfrom the above boxplots, we can observe the outliers in the different variables, maximum and minimum values of each\nunique categorical values in each column and how much they vary from each other w.r.t price.\n\n\'""\nBoxplot tells us about the outliers and what their values are, it can also tell us if our data is symmetrical and\nhow tightly our data is grouped.\nfrom the above boxplots, we can observe the outliers in the different variables, maximum and minimum values of each\nunique categorical values in each column and how much they vary from each other w.r.t price.\n\n\'\n\n'

# %%
#14
dataframe.describe()
# Out:
#         symboling  normalized-losses  ...      diesel         gas
# count  201.000000          201.00000  ...  201.000000  201.000000
# mean     0.840796          122.00000  ...    0.099502    0.900498
# std      1.254802           31.99625  ...    0.300083    0.300083
# min     -2.000000           65.00000  ...    0.000000    0.000000
# 25%      0.000000          101.00000  ...    0.000000    1.000000
# 50%      1.000000          122.00000  ...    0.000000    1.000000
# 75%      2.000000          137.00000  ...    0.000000    1.000000
# max      3.000000          256.00000  ...    1.000000    1.000000
#
# [8 rows x 19 columns]

# %%
#15
dataframe.describe(include='object')
# Out:
#           make aspiration  ... fuel-system horsepower-binned
# count      201        201  ...         201               200
# unique      22          2  ...           8                 3
# top     toyota        std  ...        mpfi               Low
# freq        32        165  ...          92               115
#
# [4 rows x 10 columns]

# %%
#16
categorical_columns=dataframe.columns[dataframe.dtypes=='object']
for i in categorical_columns:
    print(str(i)+'->column unique values are :\n'+str(dataframe[i].value_counts()))
    print('---------------------------------')
# Out:
# make->column unique values are :
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64
# ---------------------------------
# aspiration->column unique values are :
# std      165
# turbo     36
# Name: aspiration, dtype: int64
# ---------------------------------
# num-of-doors->column unique values are :
# four    115
# two      86
# Name: num-of-doors, dtype: int64
# ---------------------------------
# body-style->column unique values are :
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# ...

# %%
#17
dataframe.groupby('drive-wheels').mean()['price']
# Out:
# drive-wheels
# 4wd    10241.000000
# fwd     9244.779661
# rwd    19757.613333
# Name: price, dtype: float64

# %%
#18
categorical_columns=dataframe.columns[dataframe.dtypes=='object']
for i in categorical_columns:
    print(dataframe.groupby(i).mean()['price'])
    print('---------------------------------')
# Out:
# make
# alfa-romero      15498.333333
# audi             17859.166667
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7875.444444
# honda             8184.692308
# isuzu             8916.500000
# jaguar           34600.000000
# mazda            10652.882353
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          31400.500000
# renault           9595.000000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64
# ---------------------------------
# aspiration
# std      12542.181818
# turbo    16254.805556
# Name: price, dtype: float64
# ---------------------------------
# num-of-doors
# four    13498.034783
# two     12818.127907
# Name: price, dtype: float64
# ...

# %%
#19
dataframe_grouped=dataframe.groupby(['drive-wheels','body-style']).mean()['price']
print(dataframe_grouped)
# Out:
# drive-wheels  body-style
# 4wd           hatchback       7603.000000
#               sedan          12647.333333
#               wagon           9095.750000
# fwd           convertible    11595.000000
#               hardtop         8249.000000
#               hatchback       8396.387755
#               sedan           9811.800000
#               wagon           9997.333333
# rwd           convertible    23949.600000
#               hardtop        24202.714286
#               hatchback      14337.777778
#               sedan          21711.833333
#               wagon          16994.222222
# Name: price, dtype: float64

# %%
#20
dataframe_grouped.reset_index().pivot_table(index='drive-wheels',columns='body-style')
# Out:
#                    price                ...
# body-style   convertible       hardtop  ...         sedan         wagon
# drive-wheels                            ...
# 4wd                  NaN           NaN  ...  12647.333333   9095.750000
# fwd              11595.0   8249.000000  ...   9811.800000   9997.333333
# rwd              23949.6  24202.714286  ...  21711.833333  16994.222222
#
# [3 rows x 5 columns]

# %%
#21
gb1=dataframe.groupby(['engine-location','engine-type']).mean()['price']
gb1.reset_index().pivot_table(index='engine-location',columns='engine-type')
# Out:
#                         price                ...
# engine-type              dohc             l  ...          ohcv    rotor
# engine-location                              ...
# front            18116.416667  14627.583333  ...  25098.384615  13020.0
# rear                      NaN           NaN  ...           NaN      NaN
#
# [2 rows x 6 columns]

# %%
gb2=dataframe.groupby(['fuel-system','horsepower-binned']).mean()['price']
gb2.reset_index().pivot_table(index='fuel-system',columns='horsepower-binned')
# Out:
#                           price
# horsepower-binned          High           Low        Medium
# fuel-system
# 1bbl                        NaN   7555.545455           NaN
# 2bbl                        NaN   7433.203125           NaN
# 4bbl                        NaN  12145.000000           NaN
# idi                         NaN  12047.800000  27209.200000
# mfi                         NaN           NaN  12964.000000
# mpfi               25899.130435  11871.904762  15716.659574
# spdi                        NaN           NaN  10990.444444
# spfi                        NaN  11048.000000           NaN

# %%
#22
sns.heatmap(dataframe_grouped.reset_index().pivot_table(index='drive-wheels',columns='body-style'))

# %%
#23
from scipy.stats import pearsonr
corr, _ = pearsonr(dataframe['wheel-base'],dataframe['price'])
print('Pearsons correlation: %.3f' % corr)
print('P value: %.3f' % _)
"""
Null hypothesis is rejected as p-val<0.05
"""
# Out:
# Pearsons correlation: 0.585
# P value: 0.000
# '\nNull hypothesis is rejected as p-val<0.05\n'

# %%
from scipy.stats import f_oneway
f_oneway(dataframe['price'][dataframe['drive-wheels'] == '4wd'],
               dataframe['price'][dataframe['drive-wheels'] == 'fwd'],
               dataframe['price'][dataframe['drive-wheels'] == 'rwd'])
"""
F-statistic=67.95 suggests the between-groups variance is 67x the within-group variance
p-value is <0.05, so we reject null hypothesis i.e, both are correlated and the result is significant .
"""
# Out:
# '\nF-statistic=67.95 suggests the between-groups variance is 67x the within-group variance\np-value is <0.05, so we reject null hypothesis i.e, both are correlated and the result is significant .\n'
